# %% [markdown]
# # **Project Name**    - AirBnb Bookings Analysis

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis
# ##### **Contribution**    - Individual
# ##### **Name**            - Manoj B V

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In the project we are analyzing Airbnb’s New York City(NYC) data of 2019. NYC is not only the famous city in the world but also has top global destination for visitors attracted to its museums, entertainment, restaurants, UN offices and commerce.
#
# The project began with a comprehensive understanding of the Airbnb dataset, including data size, information like properties and their availability, price, location, reviews and ratings, exploring data related to Airbnb listings, including the number of properties listed, host characteristics, the variety of amenities available, and the occupancy rate of different properties etc. Further analysis of data to understand the significance of the reviews left by Airbnb users.
#
# Exploratory data analysis projects on Airbnb typically involve investigating patterns and trends in various aspects of the platform, such as pricing, popularity and availability of listings. This data can be used to gain insights into consumer behavior and preferences, as well as to inform marketing and business strategies for hosts and Airbnb as a company. Techniques such as data visualization and objective solution may be used to analyze the data and draw meaningful conclusions.
#
# In this type of analysis, data visualizations such as line plots, scatter plots, and bar charts are used to help identify trends, patterns, and relationships in the data. For instance, a bar chart can be used to show the distribution of properties across different neighbourhoods in a city.
#
# Overall, the exploratory data analysis provides crucial insights for the Airbnb platform to improve customer satisfaction and enhance rental revenues. The insights also benefitted renters who can use the data generated to gain a deeper understanding of the landscape and make informed decisions.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The purpose of this exploratory data analysis project is to analyze and examine the factors that influence customer bookings and preferences. The dataset used in this analysis includes information on customer demographics, subscription room type and location, minimum stays, retention rate and experience with service.
#
# The aim is to identify insights and patterns in the data that can help the company to understand the factors for customer retention and inform future decision-making regarding host listing, location, price and customer service and marketing strategies.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# 1. Recommending marketing campaign strategies and predicting the destination neighbourhood which are in high demand.
#
# 2. Using Exploratory Data Analysis, find out the most demanded room type, neighbourhood group.
#
# 3. Find the Average no. of days, guests prefer to stay in single visit in different room type in varied neighbourhood group.
#
# 4. Find out the Price Bracket in which maximum bookings happen and get most reviews.
#
# 5. Find the neighbourhood group in which maximum listings done by top hosts.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
filepath = '/content/drive/MyDrive/Airbnb NYC 2019.csv'
ab_df = pd.read_csv(filepath)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
ab_df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
ab_df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
ab_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
ab_df.drop_duplicates(inplace = True)
ab_df.shape
# Out:
# (48895, 16)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values = ab_df.isnull().sum()
missing_values
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# The missing values table shows that there are 4 columns containing null values which are name, host_name (Thought that listing 'name and host_name' doesn't really matter beacuse it might have similar entries with different ids) and last_reviews, reviews_per_month (obviously, if a listing has never received a review, its possible and valid). But reviews_per_month has its implication on data.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * This Airbnb dataset contains nearly 48,895 observations from New York
# with 16 columns of data.
#
# * The Data includes both categorical and numeric values, providing a diverse range of information about the listings.
#
# * This Dataset may be useful for analyzing trends and patterns in the Airbnb market in New York and also gain insights into the preferences and behavior of Airbnb users in the area.
#
# * This dataset contains information about Airbnb bookings in New York City in 2019. By analyzing this data, you may be able to understand the trends and patterns of Airbnb use in the NYC.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %% [markdown]
# We can see our dataset has 48895 rows/indexes and 16 columns/variables. Lets try to understand about the variables we've got here.
#
# * **id :** a unique id identifying an airbnb lisitng
# * **name :** the name of listed properties/room_type on platform
# * **host_id :** a unique id identifying an airbnb host
# * **host_name :** name under whom host is registered
# * **neighbourhood_group :** a group of area
# * **neighbourhood :** area falls under neighbourhood_group
# * **latitude :** coordinate of listing
# * **longitude :** coordinate of listing
# * **room_type :** type to categorize listing rooms
# * **price :** price of listing
# * **minimum_nights :** for the minimum nights required to pay in a single visit
# * **number_of_reviews :** total count of reviews given by visitors
# * **last_review :** content of last review given
# * **reviews_per_month :** checks of per month/reviews given per month
# * **calculated_host_listings_count :** total no. of listing registered under the host
# * **availability_365 :** the number of days for which a host is available in a year

# %%
# Dataset Columns
# Skimming through all the columns or say knowing given variables
ab_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
# We are excluding latitude & longitude as they are coordinates and id & host_id as they're unique
col = set(ab_df.columns) - {'id','host_id','latitude','longitude'}
ab_df[col].describe()
# Out:
#               price  number_of_reviews  reviews_per_month  availability_365  \
# count  48895.000000       48895.000000       38843.000000      48895.000000
# mean     152.720687          23.274466           1.373221        112.781327
# std      240.154170          44.550582           1.680442        131.622289
# min        0.000000           0.000000           0.010000          0.000000
# 25%       69.000000           1.000000           0.190000          0.000000
# 50%      106.000000           5.000000           0.720000         45.000000
# 75%      175.000000          24.000000           2.020000        227.000000
# max    10000.000000         629.000000          58.500000        365.000000
#
#        calculated_host_listings_count  minimum_nights
# count                    48895.000000    48895.000000
# mean                         7.143982        7.029962
# std                         32.952519       20.510550
# min                          1.000000        1.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# So, we get to know that some columns falls under categorical and remaining are numerical except one last_review comes under Date_Time category.
#
# **Categorical variable :** name, host_name, neighbourhood_group, neighbourhood, room_type.
# **Numerical variable :** id, host_id, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365.
# **Date_Time variable :** last_review.
# **Coordinates :** latitude, longitude.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
ab_df['id'].nunique()
#looks all the property ids are different and each listings are different here!
# Out:
# 48895

# %%
ab_df['name'].nunique()   #shows some listing names are common
# Out:
# 47905

# %%
ab_df['host_id'].nunique()    #shows that some host_ids are repeatative
# Out:
# 37457

# %%
ab_df['host_name'].nunique() # shows that 11k hosts have multiple listings
# Out:
# 11452

# %%
ab_df['neighbourhood_group'].unique()  #area of the city
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
ab_df['neighbourhood'].nunique()  #no. of neighbourhood
# Out:
# 221

# %%
ab_df["room_type"].value_counts()  #room_type listing count
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
price_value_counts = ab_df["price"].value_counts()

price_value_counts.sort_index()      #shows 673 different prices ranging from 0 to 10k
# Out:
# 0        11
# 10       17
# 11        3
# 12        4
# 13        1
#          ..
# 7703      1
# 8000      1
# 8500      1
# 9999      3
# 10000     3
# Name: price, Length: 674, dtype: int64

# %%
ab_df["calculated_host_listings_count"].unique()   #unique no of listings by hosts
# Out:
# array([  6,   2,   1,   4,   3,   5,   7,  13,  28,  11,   8,   9,  52,
#         18,  15,  19,  10,  39,  26,  29,  12,  21,  96,  14,  34,  43,
#        121,  37,  49,  31,  91,  16,  87,  33,  23,  50,  20,  25, 232,
#         17,  47, 103,  65,  30,  27, 327,  32])

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# dropping unnecessary columns

ab_df.drop(['id','last_review'], axis = 1, inplace=True)

# %%
# Examining changes after dropping unnecessary columns

ab_df.head()
# Out:
#                                                name  host_id    host_name  \
# 0                Clean & quiet apt home by the park     2787         John
# 1                             Skylit Midtown Castle     2845     Jennifer
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 4  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
#We know that reviews_per_month column have many null values, we will replace it with '0'.
#And name and host_name also have some empty indexes, replace it with 'Unknown' and 'no_name' resp.
ab_df.fillna({'reviews_per_month':0},inplace = True)
ab_df['name'].fillna('Unknown',inplace = True)
ab_df['host_name'].fillna('no_name',inplace = True)

# %%
# again examining changes
ab_df.reviews_per_month.isnull().sum()
# Out:
# 0

# %%
ab_df[['name']].isnull().values.any()
# Out:
# False

# %%
ab_df[['host_name']].isnull().values.any()
# Out:
# False

# %%
ab_df.head()
# Out:
#                                                name  host_id    host_name  \
# 0                Clean & quiet apt home by the park     2787         John
# 1                             Skylit Midtown Castle     2845     Jennifer
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 4  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
ab_df.tail()
# Out:
#                                                     name   host_id  \
# 48890    Charming one bedroom - newly renovated rowhouse   8232441
# 48891      Affordable room in Bushwick/East Williamsburg   6570630
# 48892            Sunny Studio at Historical Neighborhood  23492952
# 48893               43rd St. Time Square-cozy single bed  30985759
# 48894  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
len(ab_df[ab_df['availability_365']==0])  #checking whether how many properties are available for 365 days
# Out:
# 17533

# %%
len(ab_df[ab_df['price']==0])  #checking whether how many properties price is 0
# Out:
# 11

# %%
len(ab_df[ab_df['price']<10]) #checking how many properties have price less than $10
# Out:
# 11

# %%
len(ab_df[ab_df['price']>=500]) #This shows >=$500 listing price constitutes 2.5% of data, so these values cautiously be considered as outliers.
# Out:
# 1235

# %%
ab_df.info()  #updated data after dropping zero price columns and filling null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48895 entries, 0 to 48894
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            48895 non-null  object
#  1   host_id                         48895 non-null  int64
#  2   host_name                       48895 non-null  object
#  3   neighbourhood_group             48895 non-null  object
#  4   neighbourhood                   48895 non-null  object
#  5   latitude                        48895 non-null  float64
#  6   longitude                       48895 non-null  float64
#  7   room_type                       48895 non-null  object
#  8   price                           48895 non-null  int64
#  9   minimum_nights                  48895 non-null  int64
#  10  number_of_reviews               48895 non-null  int64
#  11  reviews_per_month               48895 non-null  float64
# ...

# %%
ab_df['host_name'].value_counts()[:5] #top 5 hosts listing counts in entire dataset
# Out:
# Michael         417
# David           403
# Sonder (NYC)    327
# John            294
# Alex            279
# Name: host_name, dtype: int64

# %%
#Maximum listings by hosts in entire dataset with unique listings within neighbourhood_group and this table gives partial answer for 5th objective.
hosts_listings = ab_df.groupby(['host_name','host_id','neighbourhood_group'])['calculated_host_listings_count'].max().reset_index()
hosts_listings.sort_values(by='calculated_host_listings_count', ascending=False).head(10)
# Out:
#                host_name    host_id neighbourhood_group  \
# 33329       Sonder (NYC)  219517861           Manhattan
# 4885          Blueground  107434423           Manhattan
# 4884          Blueground  107434423            Brooklyn
# 19038               Kara   30283594           Manhattan
# 19673             Kazuya  137358866           Manhattan
# 19674             Kazuya  137358866              Queens
# 19672             Kazuya  137358866            Brooklyn
# 16605     Jeremy & Laura   16098958           Manhattan
# 33328             Sonder   12243051           Manhattan
# 7828   Corporate Housing   61391963           Manhattan
#
#        calculated_host_listings_count
# 33329                             327
# 4885                              232
# 4884                              232
# 19038                             121
# 19673                             103
# 19674                             103
# 19672                             103
# ...

# %%
ab_df.loc[(ab_df['neighbourhood_group']=='Manhattan') & (ab_df['host_name']=='John')]
#Same hosts have many listings in same neighbourhood_groups with different room type or same/different room_type in other neighbourhood
# Out:
#                                                     name    host_id host_name  \
# 429                    NYC - Sunny Greenwich Village 1br     715807      John
# 1190                    Cozy Room in Lively East Village    2267153      John
# 1535                         The heart of the metropolis    3561489      John
# 1585                     Heart of Harlem 1 BR Garden apt    3726131      John
# 2124                   Great Room in Lively East Village    2267153      John
# ...                                                  ...        ...       ...
# 46539   Prime Modern 2 BR East Village Apt nearby Subway    5569222      John
# 47078               Time square Hell’s Kitchen  2bedroom  245518352      John
# 47209          Modern Studio Few Steps From Times Square  260807399      John
# 47624                 Gorgeous Duplex 2BED/1.5BA  Modern  269242923      John
# 48705  Hidden gem! Cozy home in heart of Lower East Side   70653354      John
#
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# From the above experiments we get some more insights like :
#
# * Entire home/apt have highest listings followed by Private room and Shared room have miniscule contribution.
# * Unique host_name number and above experiment shows that one host have many roomtype and/or more than one listing in same and/or different neighbourhood.
# * Overall listing has distributed in 5 neighbourhood_group which are having over 200 neighbourhoods. Its price goes upto 10k.
# * After inspection I figured out that a particular property name have one particular host_name hosted by that same individual but a particular host_name can have multiple properties in a neighbourhood_group or neighbourhood.
# * From the unique ids we get to know that all the property ids are different and each listings are different here.
# * By experimenting we get to know that in columns "price" and "availability_365" shows zero cost and not available throughout year respectively.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
top_20_neighbours = ab_df['neighbourhood'].value_counts()[:20]
top_20_neighbours.plot(kind='bar',color = 'green')
plt.xlabel('neighbourhood')
plt.ylabel('counts in entire NYC')
plt.title('Top neighbours in entire NYC on the basis of count listings')
# Out:
# Text(0.5, 1.0, 'Top neighbours in entire NYC on the basis of count listings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In Bar chart we can easily visualize and understand categorical data over the values that they represent.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Williamsburg, Bedford-Stuyvesant and Harlem are the 3 neighbourhood which has most of no. of bookings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# With the help of this data we can find target places to improve services and it will also help to get profit by limiting the advertisement market area so we can minimize the cost and increase the profit.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
avg_price = ab_df.groupby(['neighbourhood_group'])['price'].mean()
avg_p = avg_price.sort_values(ascending = False)[:10]
a = avg_p.plot.bar(figsize = (5,5), fontsize = 9,color = 'indigo')
a.set_xlabel('neighbourhood group',fontsize = 10)
a.set_ylabel('average size',fontsize = 10)
a.set_title('average price in different neighbourhood groups',fontsize = 10)
# Out:
# Text(0.5, 1.0, 'average price in different neighbourhood groups')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In Bar chart we can easily visualize and understand categorical data over the values that they represent.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that Manhattan has the most average price in the neighbourhood group. This shows the demand for the Manhattan over others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The higher average price shows, listing price can be made feasible for making more profit as well as more listings can be done in the high demand neighbourhood group.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(6, 22))
ax = axes.flatten()

no_of_booking_neighbourhood_group = ab_df["neighbourhood_group"].value_counts()
no_of_booking_neighbourhood_group.plot.pie(autopct='%1.2f%%', ylabel = "",figsize=(8,8), ax=ax[0])
plt.title('%_of_booking_neighbourhood_group', fontsize = 12)

ab_df['neighbourhood_group'].value_counts().plot(kind='bar', figsize =(15,6), color=['r','b','y','g','m'], ax=ax[1])
# Out:
# <Axes: title={'center': '%_of_booking_neighbourhood_group'}>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are often used to represent sample data—with data points belonging to a combination of different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart shows that only Manhattan and Brooklyn have more than 85% of orders. This way we can list more properties by targetting particular neighbourhood group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights will help to increase business by targeting particular area of market which have higher number of orders and booking. Keep track of no. of listings in the area, keep eye on percentage occupancy to make sure the demand and supply doesn't mismatch.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
most_demand_room = ab_df.groupby(['room_type'])["host_id"].count()
b = most_demand_room.plot.bar(figsize = (4,4), fontsize = 10)
b.set_xlabel("room type", fontsize = 12)
b.set_ylabel("no. of bookings", fontsize = 12)
b.set_title("most demanded room type", fontsize=1)
# Out:
# Text(0.5, 1.0, 'most demanded room type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In Bar chart we can easily visualize and understand categorical data over the values that they represent.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this chart we found that shared room is least in demand and most demand room type is entire house/apt, people like to rent a entire house/apt followed by shared room. So data suggests to make sure availability and service of demanded room type.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It help us to know that most people want entire house/apt for rent so that according to our data we will try to make/list most no. of rental properties as entire house/apt or private rooms.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
new = ab_df.groupby(["room_type"])["price"].mean()
chart5 = new.plot.bar(figsize = (4,4), fontsize = 10)
chart5.set_xlabel("room type", fontsize = 12)
chart5.set_ylabel("average price", fontsize = 12)
chart5.set_title("average price in different room type", fontsize = 14)
# Out:
# Text(0.5, 1.0, 'average price in different room type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In Bar chart we can easily visualize and understand categorical data over the values that they represent.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This Chart shows the average mean price of Entire home/apt is higher as compared to remaining two room types. This also gives us profit oriented new listing approach for all stakeholders benefits.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This Chart attracts special attention to make sure the availability as well as best service for this room type for customer satisfaction and good reviews.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
ab_df.groupby('room_type')['minimum_nights'].mean().plot(figsize= (4,4), kind='bar', color='magenta')
plt.title('Average Stays in different room types', fontsize = 14)
plt.xlabel('Room types', fontsize = 12)
plt.ylabel('Average Stays', fontsize = 12 )
# Out:
# Text(0, 0.5, 'Average Stays')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In Bar chart we can easily visualize and understand categorical data over the values that they represent.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart gives us information about making adequate facilities for average days and when respective room type going to available again for booking.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By this chart we can derive business profit by making basic calculations like no. of times respective room type can be available for booking in a month and accordingly we have to decide booking price considering expenses.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Chart - visualization of each neighbourhood_group using latitude and longitude
plt.figure(figsize = (12,6))
sns.scatterplot(x = ab_df['latitude'], y = ab_df['longitude'],hue = ab_df['neighbourhood_group'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are used to observe relationships between variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Scatter plot shows Manhattan and Brooklyn has almost similar longitude that's why they both garner almost 85% of bookings. And Staten Island belongs to outskirts so has less bookings as well as listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The prime hotspots can garner more bookings, hence we should try to list more demanding room type in these locations so that we can increase overall revenue.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(22, 6))
ax = axes.flatten()

sns.lineplot(data=ab_df, x='neighbourhood_group', y='availability_365', hue='room_type', ax=ax[0])
ax[0].set_title('Room Availability throughout Neighbourhood/Room Type')

sns.scatterplot(data=ab_df, x='price', y='number_of_reviews', hue='room_type', ax=ax[1])
ax[1].set_title('Price vs Number of Reviews')
sns.despine(fig, left=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Line plot is a graph that displays data as points or check marks above a number line, showing the frequency of each value.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# First chart shows Staten Island is busiest among all, even for least demanded shared room and Manhattan and Brooklyn shows descent bookings and availability.
#
# Second chart shows negative relation between Price and no. of reviews. Usually cheaper rooms has more occupancy hence more reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The occupancy and/or vacancy in respective areas for different room type can draw attention for different required solution like listing and/or delisting room_type from neighbourhood group. And Price vs Reviews shows booking volume for reasonable Booking Price, hence revenue generation Price point range.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
fig = plt.subplots(figsize=(6, 6))

sns.countplot(data=ab_df[ab_df['availability_365']  == 365], x='neighbourhood_group', hue='room_type', palette='deep')
plt.title('No. of Properties Available 365 days', fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Countplot is used to Show the counts of observations in each categorical bin using bars.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This subplot gives us clear picture i.e. "Trend" of room_type available most during a year. e.g. Private room has most availability round the year except in Manhattan and least availability in Shared room irrespective of Neighbourhood group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# he above Subplot shows us which room type in which neighbourhood group has most as well as least availability throughout the year. Hence this data can be for listing and delisting demanded and least asked room type resp.
#
# **Negative Insight** - In Manhattan we get to know that Entire home/apt has most availability round the year and in earlier charts we also know that same room_type has most bookings but vacancy also most maybe due to more listing of same room_type in the area.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Chart - average prefered price at every neighbourhood group as per type of room
avg_price_df = ab_df.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack()
avg_price_df.plot.bar(figsize=(10,5),ylabel='Average Price calculated')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='Average Price calculated'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In Bar chart we can easily visualize and understand categorical data over the values that they represent.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart clearly shows some trends in price and room type w.r.t neighbourhood groups. This chart shows Entire home/apt has highest average price followed by Private room and Shared room. And this chart also shows Manhattan gives us most average price compared to other neighbourhood groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This chart gives us good business insight about revenue realisation like from which room type and which neighbourhood group are going to give us highest monetary benefits for ultimate goal of profit.
#
# Negative Insight: If this chart insight gets to the hosts then they won't be that much attracted towards low avg room type as well as neighbourhood group, hence business expansion may face hurdle.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
busiest_hosts = ab_df.groupby(['host_name', 'host_id','room_type'])['number_of_reviews'].max().reset_index()
busiest_hosts = busiest_hosts.sort_values(by='number_of_reviews', ascending=False).head(10)
name = busiest_hosts['host_name']
reviews = busiest_hosts['number_of_reviews']

fig = plt.figure(figsize = (8, 5))
plt.bar(name, reviews, color ='cyan', width = 0.5)
plt.xlabel("Name of the Host")
plt.ylabel("Number of Reviews")
plt.title("Busiest Hosts", fontsize=14)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In Bar chart we can easily visualize and understand categorical data over the values that they represent.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart shows that busiest hosts in top 10 are mostly Private room and few entire home/apt. That shows Private rooms have high frequency compared to others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can use busiest hosts experience and their room type for our understanding like locality, facilities, aesthetics, service by which customer getting satisfied and paying more number of visits. Accordingly we can arrange training for our host community for making positive impact like these hosts.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Most important finding outliers in Price variable
# Split the dataset by room type
entire_home_apt = ab_df[ab_df['room_type'] == 'Entire home/apt']
private_room = ab_df[ab_df['room_type'] == 'Private room']
shared_room = ab_df[ab_df['room_type'] == 'Shared room']

# Create boxplots for price
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
axs[0].boxplot(entire_home_apt['price'])
axs[0].set_title('Entire home/apt')
axs[1].boxplot(private_room['price'])
axs[1].set_title('Private room')
axs[2].boxplot(shared_room['price'])
axs[2].set_title('Shared room')
plt.show()
#This shows that price variable has many outliers in each room_type, need to be removed.

# %%
# Remove outliers from price variable for each room_type
def remove_outliers(data):
    Q1 = np.percentile(data['price'], 25)
    Q3 = np.percentile(data['price'], 75)
    IQR = Q3 - Q1
    upper_bound = Q3 + 1.5 * IQR
    lower_bound = Q1 - 1.5 * IQR
    data1 = data[(data['price'] >= lower_bound) & (data['price'] <= upper_bound)]
    return data1

entire_home_apt1 = remove_outliers(entire_home_apt)
private_room1 = remove_outliers(private_room)
shared_room1 = remove_outliers(shared_room)

# Combine the datasets in combined_df
combined_df = pd.concat([entire_home_apt1, private_room1, shared_room1], axis=0)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 6))
ax = axes.flatten()

# Show the final boxplot without outliers
sns.boxplot(x='room_type', y='price', data=combined_df, ax=ax[0])

#distplot gives us univariate here price distribution of observation.
sns.histplot(combined_df['price'], ax=ax[1])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose these graphs to know the Price distribution in overall and within room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above three Price graphs gives clearer picture of Min & Max Price, most important it shows us Price density between $1-300 but Price point extends upto 10000 dollar for some properties luxury villas also have customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The business point of view we have to list maximum properties in average booking amount of $1-300 to maximize booking frequency for host and also focus on listing of few luxurious properties to fullfill the need of rare but high paying customers.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 6))
ax = axes.flatten()

sns.violinplot(data=combined_df, x='neighbourhood_group', y='price', ax=ax[0])

sns.violinplot(data=combined_df, x='neighbourhood_group', y='price', hue='room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# After lot of deliberations picked the Violinplot to get clearer picture of most demanded price bracket for neighbourhood_group as well as room_type

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Above five violinplot for respective neighbourhood_group shows us that most demanded price range $50-100 in everywhere except Manhattan where considerable booking happens above 100 price as well.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the business perspective, company should make adequate listings in demanded price bracket and also above average price range because some Guests are ready to pay for luxury and better services.
#
# Most important 2nd plot shows Private room and Shared room doen't fetch considerable booking beyond this price bracket

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
corr = ab_df.corr(method = 'kendall')
plt.figure(figsize= (10,8))
sns.heatmap(corr, annot =True)
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Correlation Heatmap shows us visual bi-variate correlation and relationship between numerical columns of Dataframe in the form of colour shades. We get quick visualisation of large amount of data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In the Heatmap Matrix some variables have positive correlation and others have negative correlation. e.g.
#
# Positive corr : Number_of_reviews and reviews_per_month, calculated_host_listings_count and availability_365
#
# Negative corr : price and longitude, number_of_reviews and id, reviews_per_month and minimum_nights

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
#Pair Plot visualization of outlier cleaned data

sns.pairplot(combined_df, hue='room_type',
             x_vars=['price', 'number_of_reviews','reviews_per_month','availability_365'],
             y_vars=['price', 'number_of_reviews','reviews_per_month','availability_365'],
             kind='scatter', diag_kind= 'hist')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Pair plot is perfect example for showing correlation between any two required numerical variable in given dataset. It gives all considered charts in one grid like Dashboard.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The relationship between two variables and formation of separated clustres shows some insight like Price and No. of reviews have negative relationship, more price less number of reviews per month, reviews per month vs availability_365 shows less than 20 reviews per month, clustre of availability_365 vs price shows entire home/apt properties available for higher prices etc.
#
# Histogram shows every variable has its frequency, distribution and density. Also shows characteristics of skewness.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. We have find out the Top 20 neighbourhoods where number of bookings is high, we can list more no. of places/stays in these areas to realize profit.
#
# 2. Most of the guests doesn't prefer shared rooms rather choose entire home/apt and private room. Manhattan and Brooklyn are most demanded neighbourhood groups.
#
# 3. The average stays in Entire home/apt, Shared room and Private room are 8, 6 and 5 days approx. We should make sure availability of specific room type for bookings so that demand and supply doesn't mismatch.
#
# 4. Most subscribed booking price is come within the bracket of $10-400 where almost 95% booking happens as well as most reviews are also given by the guests. One more thing Private room and Entire home/apt gives most number of reviews.
#
# 5. Maximum listings done by top hosts are also concentrated in Manhattan and Brooklyn with higher prices and most bookings.
#
# We can say that hosts are also inclined to Manhattan and Brooklyn due to higher price realisation and more bookings will happen in these neighbourhood groups as we know from earlier charts; so we can ask more commission from hosts and realize more profit.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# From the above Exploratory Data Analysis of Airbnb Dataset we can conclude that:
#
# Manhattan and Brooklyn are the two distinguished, expensive & posh areas of New York. Though location of property has high effect on deciding price, but a property in popular location doesn't mean it will stay occupied for most of the time.
#
# The people who prefer to stay in Entire home or Apartment they are going to stay bit longer and same is the most booked room type in the Neighbourhood group.
#
# The findings from an exploratory data analysis project can help both company and hosts to make more effective decisions. Company can follow some parameteres to make decisions about the location, amenities, and commission to realize profit. On the other hand, Hosts can learn more about what amenities guests are looking for and how to price their property based on location.
#
# The given Airbnb Dataset has vast data but lacks in some required features because it is not easy to decide property valuation. Overall, conducting an exploratory data analysis project on Airbnb can provide valuable insights into the dynamics of the short-term rental market and enhance the user experience for both hosts and guests.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
